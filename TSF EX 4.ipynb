# %% [markdown]
# # Time Series and Forecasting Laboratory (201DSL416)
# # Name: Atharva Mahakalkar
# # Roll No: 56
# Experiment No 4: Estimating & Eliminating Trends of Aggregation, Smoothing, Polynomial Fitting.
# Maximum Marks: 10
# Understand the concept of trend in time series data with examples.
# Implement techniques for estimating and eliminating trends in time series data, including aggregation, smoothing, and polynomial fitting.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
date_range = pd.date_range(start='2022-01-01',end='2024-01-01',freq='D')
values = np.sin(np.arange(len(date_range)) * np.pi / 180) + np.random.normal(0,0.1,size=len(date_range))
date = pd.DataFrame({'Date': date_range,'Value': values})

# %%
date
# Out:
#           Date     Value
# 0   2022-01-01  0.176405
# 1   2022-01-02  0.057468
# 2   2022-01-03  0.132773
# 3   2022-01-04  0.276425
# 4   2022-01-05  0.256512
# ..         ...       ...
# 726 2023-12-28  0.011250
# 727 2023-12-29  0.246201
# 728 2023-12-30  0.220441
# 729 2023-12-31  0.215160
# 730 2024-01-01  0.123112
#
# [731 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
plt.plot(date['Date'], date['Value'], label='Orignal Data')
plt.xlabel('Date')
plt.ylabel('Values')
plt.title("Orignal Time Series Data")
plt.legend()
plt.show()

# %%
monthly_date = date.resample('M', on='Date').mean()
plt.figure(figsize=(10,6))
plt.plot(monthly_date.index, monthly_date['Value'], label='Aggregated Data')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Aggregated Time Series Data')
plt.legend()
plt.show()

# %%
smoothed_date = date['Value'].rolling(window=10).mean()
plt.figure(figsize=(10,6))
plt.plot(date['Date'], smoothed_date, label='smoothed Data')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Smoothed Time Series Data')
plt.legend()
plt.show()

# %%
ploy_coefficients = np.polyfit(date.index, date['Value'], deg=2)
poly_values = np.polyval(ploy_coefficients, date.index)
plt.figure(figsize=(10,6))
plt.plot(date['Date'], poly_values, label='Ploynomial Fitting')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Polynomaial Fitting Time Series Data')
plt.legend()
plt.show()

# %%
ploy_coefficients = np.polyfit(date.index, date['Value'], deg=3)
poly_values = np.polyval(ploy_coefficients, date.index)
plt.figure(figsize=(10,6))
plt.plot(date['Date'], poly_values, label='Ploynomial Fitting')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Polynomaial Fitting Time Series Data')
plt.legend()
plt.show()
