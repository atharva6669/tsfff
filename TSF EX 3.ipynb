# %% [markdown]
# # Time Series and Forecasting Laboratory (201DSL416)
# # Name: Atharva Grish Mahakalkar
# # Roll No: 56
# Experiment No 3: Implementation of Stationarity of a Time Series..
# Maximum Marks: 10
# Understanding Stationarity in time series.
# Learn how to check if a time series is stationary by using statistical tests.
# Implement stationary time series from non-stationary time series

# %%
from io import IncrementalNewlineDecoder
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
trainingdata = pd.read_csv("AirPassengers.csv")

# %%
trainingdata.head(10)
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121
# 5  1949-06          135
# 6  1949-07          148
# 7  1949-08          148
# 8  1949-09          136
# 9  1949-10          119

# %%
plt.rcParams.update({'figure.figsize': (12,6)})
trainingdata['#Passengers'].plot()
# Out:
# <AxesSubplot: >

# %%
trainingdata['#Passengers_diff'] = trainingdata['#Passengers'] - trainingdata['#Passengers'].shift(1)
trainingdata['#Passengers'].dropna().plot()
# Out:
# <AxesSubplot: >

# %%
trainingdata['#Passengers_diff_7'] = trainingdata['#Passengers'].shift(7)
trainingdata['#Passengers_diff_7'].dropna().plot()
# Out:
# <AxesSubplot: >

# %%
import numpy as np

trainingdata['adj_log'] = np.log(trainingdata['#Passengers'])
trainingdata['adj_sqrt'] = np.sqrt(trainingdata['#Passengers'])
trainingdata['adj_cbrt'] = np.cbrt(trainingdata['#Passengers'])

trainingdata['adj_log'].dropna().plot()
# Out:
# <AxesSubplot: >

# %%
trainingdata['adj_sqrt'].dropna().plot()
# Out:
# <AxesSubplot: >

# %%
trainingdata['#Passengers_log_diff'] = trainingdata['adj_log'] - trainingdata['adj_log'].shift(1)
trainingdata['#Passengers_log_diff'].dropna().plot()
# Out:
# <AxesSubplot: >

# %%
trainingdata['#Passengers_sqrt_diff'] = trainingdata['adj_sqrt'] - trainingdata['adj_sqrt'].shift(1)
trainingdata['#Passengers_sqrt_diff'].dropna().plot()
# Out:
# <AxesSubplot: >

# %%
trainingdata['#MA20'] = trainingdata['#Passengers'].rolling(window = 20).mean()
trainingdata['#MA20'].dropna().plot()
# Out:
# <AxesSubplot: >

# %%
trainingdata
# Out:
#        Month  #Passengers  #Passengers_diff  #Passengers_diff_7   adj_log  \
# 0    1949-01          112               NaN                 NaN  4.718499
# 1    1949-02          118               6.0                 NaN  4.770685
# 2    1949-03          132              14.0                 NaN  4.882802
# 3    1949-04          129              -3.0                 NaN  4.859812
# 4    1949-05          121              -8.0                 NaN  4.795791
# ..       ...          ...               ...                 ...       ...
# 139  1960-08          606             -16.0               417.0  6.406880
# 140  1960-09          508             -98.0               391.0  6.230481
# 141  1960-10          461             -47.0               419.0  6.133398
# 142  1960-11          390             -71.0               461.0  5.966147
# 143  1960-12          432              42.0               472.0  6.068426
#
#       adj_sqrt  adj_cbrt  #Passengers_log_diff  #Passengers_sqrt_diff   #MA20
# 0    10.583005  4.820285                   NaN                    NaN     NaN
# 1    10.862780  4.904868              0.052186               0.279775     NaN
# 2    11.489125  5.091643              0.112117               0.626345     NaN
# 3    11.357817  5.052774             -0.022990              -0.131309     NaN
# 4    11.000000  4.946087             -0.064022              -0.357817     NaN
# ..         ...       ...                   ...                    ...     ...
# 139  24.617067  8.462348             -0.026060              -0.322861  453.15
# 140  22.538855  7.979112             -0.176399              -2.078212  460.55
# 141  21.470911  7.725032             -0.097083              -1.067945  466.50
# 142  19.748418  7.306144             -0.167251              -1.722493  465.70
# 143  20.784610  7.559526              0.102279               1.036192  467.50
#
# [144 rows x 10 columns]
